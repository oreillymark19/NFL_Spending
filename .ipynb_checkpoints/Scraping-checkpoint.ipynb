# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Extraction

# %% [markdown]
# ## Salary info

# %%
# Send GET request to URL
r = requests.get("https://overthecap.com/positional-spending/")

# Convert to BeautifulSoup object
webpage = bs(r.content)

# %%
def get_year_table(year):
    """Pull html string for table rows in the specified year."""
    # Return descendent of div tags with id equal to year of interest
    data_table = webpage.find("div", id = ("y" + str(year)))
    
    # Return table rows from the extracted data table
    data_rows = data_table.find_all("tr")
    return data_rows

def pull_data(years):
    """Extract data from HTML strings and convert into a dictionary for each team. Returns list of dictionaries."""
    # Initialize empty list for team dictionaries
    salary_dicts = []
    
    # Iterate through year inputs
    for year in years:
        # Initialize empty list of table headers
        headers = [year]
        data_rows = get_year_table(year)
        
        # Iterate through extracted table rows
        for index, row in enumerate(data_rows):
            # Set year in dictionary to current year iteration
            salary_info = {'year': int(year)}
            
            # Extract headers from first row
            if index == 0:
                header_list = row.find_all("th")
                for header in header_list:
                    headers.append(header.get_text())
            # Extract data from remaining rows
            else:
                data_list = row.find_all("td")
                print("Getting", str(year), "data for", data_list[0].get_text())
                for index, header in enumerate(headers[1:]):
                    # Remove special characters from extracted text
                    if header == 'Team':
                        if data_list[index].get_text() == 'Washington':
                            salary_info[header] = 'Redskins'
                        else:
                            salary_info[header] = data_list[index].get_text()
                    else:
                        salary_info[header] = float(data_list[index].get_text().replace("$","").replace(",",""))
                # Add team salary dictionary to list    
                salary_dicts.append(salary_info)
    return salary_dicts

# %%
# Specify years of interest
years = range(2013,2022)

# Run function on years of interest
salary_dicts = pull_data(years)
# Out:
# Getting 2013 data for Eagles
# Getting 2013 data for Seahawks
# Getting 2013 data for Titans
# Getting 2013 data for Broncos
# Getting 2013 data for Giants
# Getting 2013 data for Texans
# Getting 2013 data for Saints
# Getting 2013 data for Vikings
# Getting 2013 data for Chargers
# Getting 2013 data for Falcons
# Getting 2013 data for Lions
# Getting 2013 data for 49ers
# Getting 2013 data for Jets
# Getting 2013 data for Packers
# Getting 2013 data for Patriots
# Getting 2013 data for Washington
# Getting 2013 data for Bears
# Getting 2013 data for Panthers
# Getting 2013 data for Cardinals
# Getting 2013 data for Cowboys
# Getting 2013 data for Colts
# Getting 2013 data for Chiefs
# Getting 2013 data for Rams
# Getting 2013 data for Buccaneers
# Getting 2013 data for Steelers
# Getting 2013 data for Jaguars
# Getting 2013 data for Bengals
# Getting 2013 data for Ravens
# Getting 2013 data for Bills
# Getting 2013 data for Dolphins
# Getting 2013 data for Browns
# Getting 2013 data for Raiders
# Getting 2014 data for Falcons
# Getting 2014 data for Saints
# Getting 2014 data for Broncos
# Getting 2014 data for Chargers
# Getting 2014 data for Rams
# Getting 2014 data for Eagles
# Getting 2014 data for Bears
# Getting 2014 data for Dolphins
# Getting 2014 data for Vikings
# Getting 2014 data for Texans
# Getting 2014 data for 49ers
# Getting 2014 data for Giants
# Getting 2014 data for Lions
# Getting 2014 data for Washington
# Getting 2014 data for Jets
# Getting 2014 data for Titans
# Getting 2014 data for Patriots
# Getting 2014 data for Chiefs
# Getting 2014 data for Steelers
# Getting 2014 data for Bengals
# Getting 2014 data for Packers
# Getting 2014 data for Cowboys
# Getting 2014 data for Cardinals
# 277  13400522.0   95204222.0
# 278  19820000.0   79102728.0
# 279  29459389.0   84276580.0
# 280  20648545.0   76433196.0
# 281  20033308.0   94309836.0
# 282  17191918.0   90196421.0
# 283  26190641.0   86551006.0
# 284   7651490.0   91768827.0
# 285  16479265.0   64351761.0
# 286  32862311.0   90268300.0
# 287   9750953.0   71081936.0

# %% [markdown]
# ## Performance Extraction

# %%
from sportsipy.nfl.teams import Teams

# %%
wins = pd.DataFrame()

for year in range(2013, 2021):
    for team in Teams(year):
        name = team.name.rsplit(' ', 1)[-1]
        if name == 'Team':
            name = 'Redskins'
        wins.loc[name, year] = team.wins

wins = wins.reset_index().rename(columns = {"index":"Team"})
wins = pd.melt(wins, id_vars = ['Team'], value_vars = list(wins.columns[1:]), var_name='year', value_name='wins')
wins
# Out:
#            Team  year  wins
# 0       Broncos  2013  13.0
# 1         Bears  2013   8.0
# 2      Patriots  2013  12.0
# 3        Eagles  2013  10.0
# 4       Cowboys  2013   8.0
# ..          ...   ...   ...
# 251      Giants  2020   6.0
# 252        Jets  2020   2.0
# 253  Buccaneers  2020  11.0
# 254      Texans  2020   4.0
# 255     Jaguars  2020   1.0
#
# [256 rows x 3 columns]

# %%
full_df = pd.merge(salary_df, wins, how = 'inner', on = ['Team','year'])
full_df['Team'].unique()
# Out:
# array(['Eagles', 'Seahawks', 'Titans', 'Broncos', 'Giants', 'Texans',
#        'Saints', 'Vikings', 'Chargers', 'Falcons', 'Lions', '49ers',
#        'Jets', 'Packers', 'Patriots', 'Redskins', 'Bears', 'Panthers',
#        'Cardinals', 'Cowboys', 'Colts', 'Chiefs', 'Rams', 'Buccaneers',
#        'Steelers', 'Jaguars', 'Bengals', 'Ravens', 'Bills', 'Dolphins',
#        'Browns', 'Raiders'], dtype=object)

# %%
sns.pairplot(full_df, vars = list(full_df.columns[2:]))

# %%
full_df[2:].corr()
# Out:
#                QB        RB        WR        TE        OL   Offense       IDL  \
# QB       1.000000 -0.149707  0.035321  0.202176  0.208588  0.620957 -0.104326
# RB      -0.149707  1.000000 -0.055494 -0.070293  0.071582  0.123442  0.052887
# WR       0.035321 -0.055494  1.000000  0.061312  0.263139  0.545661  0.134980
# TE       0.202176 -0.070293  0.061312  1.000000  0.153327  0.400381  0.018247
# OL       0.208588  0.071582  0.263139  0.153327  1.000000  0.747115  0.151029
# Offense  0.620957  0.123442  0.545661  0.400381  0.747115  1.000000  0.091293
# IDL     -0.104326  0.052887  0.134980  0.018247  0.151029  0.091293  1.000000
# EDGE     0.041096 -0.030506  0.146530  0.200419  0.168963  0.198666 -0.102711
# LB       0.134707  0.107410  0.041411  0.095674  0.145114  0.195979 -0.049824
# S        0.049544  0.059198  0.089746  0.070007  0.050011  0.111364 -0.046358
# CB      -0.055208 -0.001720  0.189163 -0.068377  0.106097  0.085187  0.230246
# Defense  0.005474  0.066394  0.281835  0.138479  0.283660  0.297329  0.527158
# wins     0.114695  0.004596  0.041481  0.108631  0.057786  0.125479 -0.035779
#
#              EDGE        LB         S        CB   Defense      wins
# QB       0.041096  0.134707  0.049544 -0.055208  0.005474  0.114695
# RB      -0.030506  0.107410  0.059198 -0.001720  0.066394  0.004596
# WR       0.146530  0.041411  0.089746  0.189163  0.281835  0.041481
# TE       0.200419  0.095674  0.070007 -0.068377  0.138479  0.108631
# OL       0.168963  0.145114  0.050011  0.106097  0.283660  0.057786
# Offense  0.198666  0.195979  0.111364  0.085187  0.297329  0.125479
# IDL     -0.102711 -0.049824 -0.046358  0.230246  0.527158 -0.035779
# EDGE     1.000000 -0.061216  0.024302  0.013141  0.471585  0.165904
# LB      -0.061216  1.000000 -0.024644 -0.077066  0.240544  0.088939
# S        0.024302 -0.024644  1.000000  0.038759  0.336156  0.181204
# CB       0.013141 -0.077066  0.038759  1.000000  0.595613  0.014069
# Defense  0.471585  0.240544  0.336156  0.595613  1.000000  0.168238
# wins     0.165904  0.088939  0.181204  0.014069  0.168238  1.000000

# %%
from sklearn.preprocessing import StandardScaler

full_df_scaled = full_df.copy()
y = full_df['wins'].copy()
scaled_features = StandardScaler().fit_transform(full_df_scaled.loc[:,'QB':'Defense'])

full_df_scaled.loc[:,'QB':'Defense'] = scaled_features

sns.scatterplot(data = full_df_scaled, x = 'Offense', y = 'Defense', hue = 'wins')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 3)
principalComponents = pca.fit_transform(full_df_scaled.loc[:,'QB':'Defense'])

loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3'], index=list(full_df_scaled.loc[:,'QB':'Defense'].columns))
print(loadings.sort_values('PC1'))


PCdf = pd.DataFrame(data = principalComponents, columns=['PC1', 'PC2', 'PC3'])
PCdf_full = pd.concat([PCdf, y], axis = 1)
# Out:
#               PC1       PC2       PC3
# Offense -0.506352 -0.316163  0.132514
# Defense -0.421558  0.442854 -0.109966
# OL      -0.408575 -0.152240  0.211795
# WR      -0.329942  0.031332 -0.001765
# QB      -0.238025 -0.434492 -0.027501
# EDGE    -0.230583  0.034092 -0.570862
# TE      -0.229335 -0.249183 -0.277684
# CB      -0.214496  0.468212 -0.012660
# IDL     -0.191971  0.419149  0.243965
# LB      -0.149588 -0.133047  0.404528
# S       -0.145629  0.098975 -0.188778
# RB      -0.035166  0.072934  0.512620

# %%
PCdf_full.corr()
# Out:
#                PC1           PC2           PC3      wins
# PC1   1.000000e+00 -5.270814e-16 -1.660677e-17 -0.168305
# PC2  -5.270814e-16  1.000000e+00 -3.756060e-17 -0.041598
# PC3  -1.660677e-17 -3.756060e-17  1.000000e+00 -0.111732
# wins -1.683052e-01 -4.159777e-02 -1.117318e-01  1.000000

# %%
dvoa_df = pd.DataFrame()
for year in range(2013, 2021):
    overall_df = pd.read_csv("./DVOA/" + str(year) + " Team DVOA Ratings Overall.csv").sort_values(by = 'Team')
    overall_df['year'] = year
    offense_df = pd.read_csv("./DVOA/" + str(year) + " Team DVOA Ratings Offense.csv").sort_values(by = 'Team')
    defense_df = pd.read_csv("./DVOA/" + str(year) + " Team DVOA Ratings Defense.csv").sort_values(by = 'Team')
    year_df = pd.concat([overall_df[['Team',
                                     'year',
                                     'Total DVOA',
                                     'Offense DVOA',
                                     'Defense DVOA',
                                     'Special Teams DVOA',
                                     'Unadj. Total VOA','Variance']],
                         offense_df[['Pass DVOA',
                                    'Rush DVOA',
                                    'Unadj. Pass VOA',
                                    'Unadj. Rush VOA',
                                    'Variance']],
                         defense_df[['Pass DVOA',
                                    'Rush DVOA',
                                    'Unadj. Pass VOA',
                                    'Unadj. Rush VOA',
                                    'Variance']]], axis = 1)
    dvoa_df = pd.concat([dvoa_df, year_df])
    
dvoa_df.reset_index(drop = True, inplace = True)
team_names = pd.read_csv("./Teams.csv")
dvoa_df = pd.merge(team_names, dvoa_df, left_on = 'City', right_on = 'Team', suffixes = ('','_drop'))
dvoa_df.drop(['City', 'Team_drop'], axis = 1, inplace = True)
dvoa_df
# Out:
#          Team    year Total DVOA Offense DVOA Defense DVOA Special Teams DVOA  \
# 0    Patriots  2013.0      17.9%        16.5%         5.3%               6.7%
# 1    Patriots  2014.0      21.6%        13.9%        -2.0%               5.7%
# 2    Patriots  2015.0      22.6%        15.4%        -3.4%               3.9%
# 3    Patriots  2016.0      25.1%        21.2%        -1.6%               2.3%
# 4    Patriots  2017.0      22.2%        27.9%        12.0%               6.3%
# ..        ...     ...        ...          ...          ...                ...
# 251   Raiders  2018.0     -23.4%        -7.7%        14.2%              -1.6%
# 252   Raiders  2019.0     -12.7%         5.4%        15.8%              -2.3%
# 253      Rams  2013.0       5.4%        -9.7%        -8.9%               6.3%
# 254      Rams  2014.0      -0.7%       -11.0%        -6.9%               3.5%
# 255      Rams  2015.0       0.9%       -15.5%       -14.0%               2.4%
#
#     Unadj. Total VOA Variance Pass DVOA Rush DVOA Unadj. Pass VOA  \
# 0              16.7%     4.7%     37.3%     -8.4%           33.8%
# 1              19.3%    17.3%     36.0%      6.6%           36.3%
# 2              24.2%    12.4%     24.5%      8.4%           21.7%
# 3              30.5%    12.7%     51.1%      2.4%           47.7%
# 4              24.4%    11.1%     30.9%      0.4%           29.1%
# ..               ...      ...       ...       ...             ...
# 251           -30.2%    22.0%    -22.6%    -24.6%          -23.0%
# 252           -11.6%    19.4%      3.8%    -19.6%            2.0%
# 253             2.1%    23.5%     13.7%     -6.9%           15.8%
# 254            -2.2%    27.8%      6.2%      0.4%            6.7%
# 255            -5.0%    14.6%     24.5%    -17.9%           29.2%
#
#     Unadj. Rush VOA Variance Pass DVOA Rush DVOA Unadj. Pass VOA  \
# 0             -8.9%     7.1%    -12.7%    -10.4%          -16.0%
# 1              4.0%     7.6%     -5.6%    -15.3%           -4.1%
# 2              9.7%     4.5%     -0.9%    -33.9%           -5.6%
# 3              4.0%     3.5%    -24.5%     -8.4%          -19.4%
# 4             -0.3%    10.1%    -10.8%    -12.2%           -3.6%
# ..              ...      ...       ...       ...             ...
# 251          -25.4%    13.7%     32.3%     -5.0%           36.5%
# 252          -20.7%     2.7%     14.1%     -1.2%           15.7%
# 253           -5.7%    11.6%      4.1%    -19.3%            1.5%
# 254            2.2%     9.2%      8.1%     -6.7%            6.0%
# 255          -13.3%     6.4%      6.8%    -12.7%            8.2%
#
#     Unadj. Rush VOA Variance
# 0            -16.2%     8.7%
# 1            -11.7%     9.4%
# 2            -35.8%     4.2%
# 3            -10.0%     6.2%
# 4             -9.7%     6.2%
# ..              ...      ...
# 251            0.1%     4.6%
# 252           -2.7%     2.5%
# 253          -19.6%     8.9%
# 254           -7.9%     8.6%
# 255          -16.5%     3.7%
#
# [256 rows x 18 columns]

# %%
full_dvoa_df = pd.merge(dvoa_df, full_df, on = ['Team','year'])
full_dvoa_df
# Out:
#          Team  year Total DVOA Offense DVOA Defense DVOA Special Teams DVOA  \
# 0    Patriots  2013      17.9%        16.5%         5.3%               6.7%
# 1    Patriots  2014      21.6%        13.9%        -2.0%               5.7%
# 2    Patriots  2015      22.6%        15.4%        -3.4%               3.9%
# 3    Patriots  2016      25.1%        21.2%        -1.6%               2.3%
# 4    Patriots  2017      22.2%        27.9%        12.0%               6.3%
# ..        ...   ...        ...          ...          ...                ...
# 251   Raiders  2018     -23.4%        -7.7%        14.2%              -1.6%
# 252   Raiders  2019     -12.7%         5.4%        15.8%              -2.3%
# 253      Rams  2013       5.4%        -9.7%        -8.9%               6.3%
# 254      Rams  2014      -0.7%       -11.0%        -6.9%               3.5%
# 255      Rams  2015       0.9%       -15.5%       -14.0%               2.4%
#
#     Unadj. Total VOA Variance Pass DVOA Rush DVOA  ...          TE  \
# 0              16.7%     4.7%     37.3%     -8.4%  ...   4150882.0
# 1              19.3%    17.3%     36.0%      6.6%  ...   7369559.0
# 2              24.2%    12.4%     24.5%      8.4%  ...  12066813.0
# 3              30.5%    12.7%     51.1%      2.4%  ...  12753868.0
# 4              24.4%    11.1%     30.9%      0.4%  ...  12917262.0
# ..               ...      ...       ...       ...  ...         ...
# 251           -30.2%    22.0%    -22.6%    -24.6%  ...  11533431.0
# 252           -11.6%    19.4%      3.8%    -19.6%  ...   5767514.0
# 253             2.1%    23.5%     13.7%     -6.9%  ...   6217555.0
# 254            -2.2%    27.8%      6.2%      0.4%  ...   8642056.0
# 255            -5.0%    14.6%     24.5%    -17.9%  ...  15475441.0
#
#              OL      Offense         IDL        EDGE          LB           S  \
# 0    22775490.0   53962506.0  15169500.0   6420702.0  10801171.0   7386653.0
# 1    15395126.0   56671568.0  10516902.0   5631786.0  12844605.0   8593385.0
# 2    21165260.0   68404435.0   7937534.0  12837644.0  12503493.0  11471634.0
# 3    26847155.0   76909925.0   5119235.0  14912527.0  13450124.0  12755434.0
# 4    22196744.0   79439335.0  10484357.0   5229052.0  13278110.0  23735041.0
# ..          ...          ...         ...         ...         ...         ...
# 251  36376204.0  100171769.0  11861506.0   2352299.0  10206380.0  11068824.0
# 252  40914105.0   94771614.0   5970975.0  10718493.0   8512658.0  19976408.0
# 253  19240160.0   47280573.0   9376091.0  13967275.0  15711252.0   3645196.0
# 254  26264010.0   65961161.0  12047009.0  21708707.0  13272617.0   4207611.0
# 255  18702572.0   55835485.0  10316492.0  37018755.0  10685780.0   8220899.0
#
#              CB     Defense  wins
# 0     8618787.0  48396813.0  12.0
# 1    15181481.0  52768159.0  12.0
# 2     4536710.0  49287015.0  12.0
# 3     4775449.0  51012769.0  14.0
# 4    16603309.0  69329869.0  13.0
# ..          ...         ...   ...
# 251  11492532.0  46981541.0   4.0
# 252   9652415.0  54830949.0   7.0
# 253  17453159.0  60152973.0   7.0
# 254   3599498.0  54835442.0   6.0
# 255   4293600.0  70535526.0   7.0
#
# [256 rows x 31 columns]
